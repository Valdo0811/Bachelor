# %%
from anomalib.data import MVTecAD
from anomalib.models import Patchcore
from anomalib.engine import Engine
import torch

torch.set_float32_matmul_precision('medium')

# %%
from pytorch_lightning import LightningDataModule
from torch.utils.data import DataLoader
from anomalib.data.dataclasses import ImageBatch

class CustomDataModule(LightningDataModule):
    def __init__(
        self,
        root: str = "./dataset/mvtec_anomaly_detection/bottle",
        category: str = "bottle",
        train_batch_size: int = 32,
        image_size = tuple[int, int] = (256, 256),
        **kwargs
    ):
        super().__init__()
        self.root = root
        self.category = category
        self.image_size = image_size
        self.train_batch_size = train_batch_size

    def setup(self, stage: str | None = None):
        """Initialize datasets."""
        if stage == "fit" or stage is None:
            self.train_dataset = CustomDataset(
                root=self.root,
                category=self.category,
                split="train"
            )

    def train_dataloader(self) -> DataLoader:
        """Create train dataloader."""
        return DataLoader(
            dataset=self.train_dataset,
            batch_size=self.train_batch_size,
            shuffle=True,
            collate_fn=ImageBatch.collate
        )

# %%
# Initialize model and data
datamodule = MVTecAD()
model = Patchcore()
# Out:
# Default path to local dataset ./datasets/MVTecAD is deprecated and will be moved to C:\Users\falzb\AppData\Local\anomalib\anomalib\Cache\datasets\MVTecAD in v2.6.0.
# mvtecad: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 datamodule = MVTecAD()
#       3 model = Patchcore()
# ----> 4 datamodule.prepare_data()
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\data\datamodules\image\mvtecad.py:220, in MVTecAD.prepare_data(self)
#     218     logger.info("Found the dataset.")
#     219 else:
# --> 220     download_and_extract(self.root, DOWNLOAD_INFO)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\data\utils\download.py:313, in download_and_extract(root, info)
#     310 if info.url.startswith("http://") or info.url.startswith("https://"):
#     311     with DownloadProgressBar(unit="B", unit_scale=True, miniters=1, desc=info.name) as progress_bar:
#     312         # nosemgrep: python.lang.security.audit.dynamic-urllib-use-detected.dynamic-urllib-use-detected # noqa: ERA001, E501
# --> 313         urlretrieve(  # noqa: S310  # nosec B310
#     314             url=f"{info.url}",
#     315             filename=downloaded_file_path,
#     316             reporthook=progress_bar.update_to,
#     317         )
#     318     logger.info("Checking the hash of the downloaded file.")
#     319     check_hash(downloaded_file_path, info.hashsum)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)    236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404:

# %%
# Train using the Engine
engine = Engine(accelerator="cpu")
engine.fit(model=model, datamodule=datamodule)
# Out:
# Exception in thread Thread-10 (_readerthread):
# Traceback (most recent call last):
#   File "c:\Users\falzb\anaconda3\envs\sam3\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\falzb\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\falzb\anaconda3\envs\sam3\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\falzb\anaconda3\envs\sam3\Lib\subprocess.py", line 1599, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "<frozen codecs>", line 322, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x81 in position 21: invalid start byte
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# mvtecad: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Train using the Engine
#       2 engine = Engine(accelerator="cpu")
# ----> 3 engine.fit(model=model, datamodule=datamodule)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\engine\engine.py:421, in Engine.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     413     self.trainer.validate(
#     414         model,
#     415         val_dataloaders,
#    (...)    418         weights_only=False,
#     419     )
#     420 else:
# --> 421     self.trainer.fit(model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only=False)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\trainer.py:584, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     582 self.training = True
#     583 self.should_stop = False
# --> 584 call._call_and_handle_interrupt(
#     585     self,
#     586     self._fit_impl,
#     587     model,
#     588     train_dataloaders,
#     589     val_dataloaders,
#     590     datamodule,
#     591     ckpt_path,
#     592     weights_only,
#     593 )
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\trainer.py:630, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     623     download_model_from_registry(ckpt_path, self)
#     624 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     625     self.state.fn,
#     626     ckpt_path,
#     627     model_provided=True,
#     628     model_connected=self.lightning_module is not None,
#     629 )
# --> 630 self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     632 assert self.state.stopped
#     633 self.training = False
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1037, in Trainer._run(self, model, ckpt_path, weights_only)
#    1034 self.__setup_profiler()
#    1036 log.debug(f"{self.__class__.__name__}: preparing data")
# -> 1037 self._data_connector.prepare_data()
#    1039 call._call_setup_hook(self)  # allow user to set up LightningModule in accelerator environment
#    1040 log.debug(f"{self.__class__.__name__}: configuring model")
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:95, in _DataConnector.prepare_data(self)
#      93     with _InfiniteBarrier():
#      94         if (prepare_data_per_node and local_rank_zero) or (not prepare_data_per_node and global_rank_zero):
# ---> 95             call._call_lightning_datamodule_hook(trainer, "prepare_data")
#      97 # handle lightning module prepare data:
#      98 if lightning_module is not None and is_overridden("prepare_data", lightning_module):
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\call.py:199, in _call_lightning_datamodule_hook(trainer, hook_name, *args, **kwargs)
#     197 if callable(fn):
#     198     with trainer.profiler.profile(f"[LightningDataModule]{trainer.datamodule.__class__.__name__}.{hook_name}"):
# --> 199         return fn(*args, **kwargs)
#     200 return None
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\data\datamodules\image\mvtecad.py:220, in MVTecAD.prepare_data(self)
#     218     logger.info("Found the dataset.")
#     219 else:
# --> 220     download_and_extract(self.root, DOWNLOAD_INFO)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\data\utils\download.py:313, in download_and_extract(root, info)
#     310 if info.url.startswith("http://") or info.url.startswith("https://"):
#     311     with DownloadProgressBar(unit="B", unit_scale=True, miniters=1, desc=info.name) as progress_bar:
#     312         # nosemgrep: python.lang.security.audit.dynamic-urllib-use-detected.dynamic-urllib-use-detected # noqa: ERA001, E501
# --> 313         urlretrieve(  # noqa: S310  # nosec B310
#     314             url=f"{info.url}",
#     315             filename=downloaded_file_path,
#     316             reporthook=progress_bar.update_to,
#     317         )
#     318     logger.info("Checking the hash of the downloaded file.")
#     319     check_hash(downloaded_file_path, info.hashsum)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)    236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404:

# %%
# Get predictions
predictions = engine.predict(model=model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ckpt_path is not provided. Model weights will not be loaded.
# mvtecad: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Get predictions
# ----> 2 predictions = engine.predict(model=model, datamodule=datamodule)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\engine\engine.py:687, in Engine.predict(self, model, dataloaders, datamodule, dataset, return_predictions, ckpt_path, data_path)
#     677     logger.info("Running validation before predicting to collect normalization metrics and/or thresholds.")
#     678     self.trainer.validate(
#     679         model,
#     680         dataloaders=None,
#    (...)    684         weights_only=False,
#     685     )
# --> 687 return self.trainer.predict(model, dataloaders, datamodule, return_predictions, ckpt_path, weights_only=False)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\trainer.py:941, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path, weights_only)
#     939 self.state.status = TrainerStatus.RUNNING
#     940 self.predicting = True
# --> 941 return call._call_and_handle_interrupt(
#     942     self,
#     943     self._predict_impl,
#     944     model,
#     945     dataloaders,
#     946     datamodule,
#     947     return_predictions,
#     948     ckpt_path,
#     949     weights_only,
#     950 )
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\trainer.py:990, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path, weights_only)
#     986     download_model_from_registry(ckpt_path, self)
#     987 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     988     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     989 )
# --> 990 results = self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     992 assert self.state.stopped
#     993 self.predicting = False
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1037, in Trainer._run(self, model, ckpt_path, weights_only)
#    1034 self.__setup_profiler()
#    1036 log.debug(f"{self.__class__.__name__}: preparing data")
# -> 1037 self._data_connector.prepare_data()
#    1039 call._call_setup_hook(self)  # allow user to set up LightningModule in accelerator environment
#    1040 log.debug(f"{self.__class__.__name__}: configuring model")
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:95, in _DataConnector.prepare_data(self)
#      93     with _InfiniteBarrier():
#      94         if (prepare_data_per_node and local_rank_zero) or (not prepare_data_per_node and global_rank_zero):
# ---> 95             call._call_lightning_datamodule_hook(trainer, "prepare_data")
#      97 # handle lightning module prepare data:
#      98 if lightning_module is not None and is_overridden("prepare_data", lightning_module):
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\lightning\pytorch\trainer\call.py:199, in _call_lightning_datamodule_hook(trainer, hook_name, *args, **kwargs)
#     197 if callable(fn):
#     198     with trainer.profiler.profile(f"[LightningDataModule]{trainer.datamodule.__class__.__name__}.{hook_name}"):
# --> 199         return fn(*args, **kwargs)
#     200 return None
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\data\datamodules\image\mvtecad.py:220, in MVTecAD.prepare_data(self)
#     218     logger.info("Found the dataset.")
#     219 else:
# --> 220     download_and_extract(self.root, DOWNLOAD_INFO)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\site-packages\anomalib\data\utils\download.py:313, in download_and_extract(root, info)
#     310 if info.url.startswith("http://") or info.url.startswith("https://"):
#     311     with DownloadProgressBar(unit="B", unit_scale=True, miniters=1, desc=info.name) as progress_bar:
#     312         # nosemgrep: python.lang.security.audit.dynamic-urllib-use-detected.dynamic-urllib-use-detected # noqa: ERA001, E501
# --> 313         urlretrieve(  # noqa: S310  # nosec B310
#     314             url=f"{info.url}",
#     315             filename=downloaded_file_path,
#     316             reporthook=progress_bar.update_to,
#     317         )
#     318     logger.info("Checking the hash of the downloaded file.")
#     319     check_hash(downloaded_file_path, info.hashsum)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)    236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Users\falzb\anaconda3\envs\sam3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404:

# %%
# Configure pre-processor to reproduce paper settings
pre_processor = Patchcore.configure_pre_processor(
    image_size=(256, 256),
    center_crop_size=(224, 224)
)
